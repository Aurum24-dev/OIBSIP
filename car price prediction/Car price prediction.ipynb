# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/car price prediction/car data.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.shape
# Out:
# (301, 9)

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# ...

# %% [markdown]
# Data Visualisation

# %%
print(df.Car_Name.value_counts())
# Out:
# city                        26
# corolla altis               16
# verna                       14
# fortuner                    11
# brio                        10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: Car_Name, Length: 98, dtype: int64

# %%
print(df.Fuel_Type.value_counts())
# Out:
# Petrol    239
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64

# %%
fuel_counts = df.Fuel_Type.value_counts()

# Set Seaborn style
sns.set(style="whitegrid")

# Set up the pie chart
plt.figure(figsize=(5,5))  # Optional: set the figure size
colors = sns.color_palette('bright')[0:len(fuel_counts)]  # Use Seaborn's color palette
plt.pie(fuel_counts.values, labels=fuel_counts.index, autopct='%1.1f%%', startangle=140, colors=colors)

# Customize the plot
plt.title('Distribution of Cars by fuel type')
plt.show()

# %%
print(df.Selling_type.value_counts())
# Out:
# Dealer        195
# Individual    106
# Name: Selling_type, dtype: int64

# %%
sellingtype_counts =df.Selling_type.value_counts()

# Set Seaborn style
sns.set(style="whitegrid")

# Set up the pie chart
plt.figure(figsize=(5,5))  # Optional: set the figure size
colors = sns.color_palette('pastel')[0:len(sellingtype_counts)]  # Use Seaborn's color palette
plt.pie(sellingtype_counts.values, labels=sellingtype_counts.index, autopct='%1.1f%%', startangle=140, colors=colors)

# Customize the plot
plt.title('Distribution of Cars by Selling type')
plt.show()

# %%
print(df.Transmission.value_counts())
# Out:
# Manual       261
# Automatic     40
# Name: Transmission, dtype: int64

# %%
transmission_counts =df.Transmission.value_counts()
# Set Seaborn style
sns.set(style="whitegrid")

# Set up the pie chart
plt.figure(figsize=(5,5))  # Optional: set the figure size
colors = sns.color_palette('coolwarm')[0:len(transmission_counts)]  # Use Seaborn's color palette
plt.pie(transmission_counts.values, labels=transmission_counts.index, autopct='%1.1f%%', startangle=140, colors=colors)

# Customize the plot
plt.title('Distribution of Cars by Selling type')
plt.show()

# %%
df.replace({'Fuel_Type':{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)
df.replace({'Selling_type':{'Dealer':0,'Individual':1}},inplace=True)
df.replace({'Transmission':{'Manual':0,'Automatic':1}},inplace=True)

# %%
df.head
# Out:
# <bound method NDFrame.head of     Car_Name  Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000          0
# 1        sx4  2013           4.75           9.54       43000          1
# 2       ciaz  2017           7.25           9.85        6900          0
# 3    wagon r  2011           2.85           4.15        5200          0
# 4      swift  2014           4.60           6.87       42450          1
# ..       ...   ...            ...            ...         ...        ...
# 296     city  2016           9.50          11.60       33988          1
# 297     brio  2015           4.00           5.90       60000          0
# 298     city  2009           3.35          11.00       87934          0
# 299     city  2017          11.50          12.50        9000          1
# 300     brio  2016           5.30           5.90        5464          0
#
#      Selling_type  Transmission  Owner
# ...

# %%
x=df.drop(['Car_Name','Selling_Price'],axis=1)
y=df['Selling_Price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=2)

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
model.fit(x_train,y_train)

# %%
from sklearn.metrics import mean_squared_error, r2_score
def scores(y_test,y_pred):
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    print("Root_Mean_Squared_error: ", rmse)
    print("R2 Score (Accuracy): {:.2f}%".format(r2 * 100))

# %%
y_pred2=model.predict(x_test)
scores(y_test,y_pred2)
# Out:
# Root_Mean_Squared_error:  0.9553119276555061
# R2 Score (Accuracy): 93.67%
